# %%
#import pandas and numpy

import pandas as pd
import numpy as np

# %%
#enter a data
dict={
    "name":['Harry','Rohan','Skillf','Subh'],
    "marks":[90,87,79,85],
    "city":['Lucknow','Mumbai','Delhi','Banglore']
}

# %%
#showing data frame
df = pd.DataFrame(dict)

# %%
print(df)  #row indentify by index and column by name
# Out:
#      name  marks      city
# 0   Harry     90   Lucknow
# 1   Rohan     87    Mumbai
# 2  Skillf     79     Delhi
# 3    Subh     85  Banglore

# %%
#to export data in csv or excel
df.to_csv('Student.csv')

# %%
# if we don't want to save index
df.to_csv('student_without_index.csv',index=False)

# %%
#to see staring rows
df.head(2)  #if head is empty it shows few starting data
# Out:
#     name  marks     city
# 0  Harry     90  Lucknow
# 1  Rohan     87   Mumbai

# %%
#shows numerical column statistic data
df.describe()
# Out:
#            marks
# count   4.000000
# mean   85.250000
# std     4.645787
# min    79.000000
# 25%    83.500000
# 50%    86.000000
# 75%    87.750000
# max    90.000000

# %%
#to read data
print(pd.read_csv('student_without_index.csv'))
# Out:
#      name  marks      city
# 0   Harry     90   Lucknow
# 1   Rohan     87    Mumbai
# 2  Skillf     79     Delhi
# 3    Subh     85  Banglore

# %%
train=pd.read_csv('train.csv')

# %%
train
# Out:
#    TRAIN  SPEED      CITY
# 0  12345      50  LUCKNOW
# 1  12546     104    DELHI
# 2  48955      56     PUNE
# 3  56897      85   MUMBAI

# %%
train['SPEED ']
# Out:
# 0     50
# 1    104
# 2     56
# 3     85
# Name: SPEED , dtype: int64

# %%
train['SPEED '][0]
# Out:
# 50

# %%
train['SPEED '][0]=50  #to change value
# Out:
# C:\Users\nav7u\AppData\Local\Temp\ipykernel_428\1691662561.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['SPEED '][0]=50  #to change value

# %%
train['SPEED '][0]
# Out:
# 50

# %%
train
# Out:
#    TRAIN  SPEED      CITY
# 0  12345      50  LUCKNOW
# 1  12546     104    DELHI
# 2  48955      56     PUNE
# 3  56897      85   MUMBAI

# %%
train.to_csv('train.csv',index=False)

# %%
#to change index from o 1 2 ... to name
train.index=['first','second','third','fourth']

# %%
train
# Out:
#         TRAIN  SPEED      CITY
# first   12345      50  LUCKNOW
# second  12546     104    DELHI
# third   48955      56     PUNE
# fourth  56897      85   MUMBAI

# %%
#to generate random series
newdf=pd.DataFrame(np.random.rand(50,5),index=np.arange(50))

# %%
newdf
# Out:
#            0         1         2         3         4
# 0   0.915745  0.071505  0.269820  0.089495  0.079508
# 1   0.116828  0.467167  0.108266  0.682470  0.455040
# 2   0.057368  0.589525  0.850322  0.737719  0.963583
# 3   0.794483  0.859540  0.421362  0.375615  0.444670
# 4   0.232749  0.823588  0.982229  0.002032  0.332501
# 5   0.970108  0.267476  0.327169  0.862918  0.768812
# 6   0.102828  0.953421  0.360648  0.431597  0.030185
# 7   0.182527  0.051682  0.620288  0.853434  0.324586
# 8   0.232518  0.034265  0.326712  0.813759  0.010466
# 9   0.340690  0.910038  0.293726  0.109882  0.689943
# 16  0.459326  0.725478  0.071517  0.418660  0.225552
# ...

# %%
#to make a view of dataframe
newdf2=newdf

# %%
newdf2[0][0]=9876

# %%
newdf
# Out:
#            0         1         2         3         4
# 0       9876  0.071505  0.269820  0.089495  0.079508
# 1   0.116828  0.467167  0.108266  0.682470  0.455040
# 2   0.057368  0.589525  0.850322  0.737719  0.963583
# 3   0.794483  0.859540  0.421362  0.375615  0.444670
# 4   0.232749  0.823588  0.982229  0.002032  0.332501
# 5   0.970108  0.267476  0.327169  0.862918  0.768812
# 6   0.102828  0.953421  0.360648  0.431597  0.030185
# 7   0.182527  0.051682  0.620288  0.853434  0.324586
# 8   0.232518  0.034265  0.326712  0.813759  0.010466
# 9    0.34069  0.910038  0.293726  0.109882  0.689943
# 10  0.091192  0.241515  0.235934  0.904396  0.155773
# 11  0.572926  0.409134  0.749495  0.630923  0.079969
# 12  0.191295  0.140298  0.913058  0.403997  0.425318
# 13  0.053545  0.743588  0.045677  0.746104  0.303892
# 14   0.16664  0.416513  0.639310  0.560431  0.028280
# 15  0.107258  0.495714  0.475065  0.080409  0.186404
# 16  0.225552  0.418660  0.071517  0.725478  0.459326
# ...

# %%
# to copy without changing newdf
newdf2=newdf.copy()

# %%
newdf2[0][0]=9090
# Out:
# C:\Users\nav7u\AppData\Local\Temp\ipykernel_428\3416823633.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2[0][0]=9090

# %%
newdf.columns=list("ABCDE")   #to change name of column index

# %%
newdf
# Out:
#            A         B         C         D         E
# 0       9876  0.071505  0.269820  0.089495  0.079508
# 1   0.116828  0.467167  0.108266  0.682470  0.455040
# 2   0.057368  0.589525  0.850322  0.737719  0.963583
# 3   0.794483  0.859540  0.421362  0.375615  0.444670
# 4   0.232749  0.823588  0.982229  0.002032  0.332501
# 5   0.970108  0.267476  0.327169  0.862918  0.768812
# 6   0.102828  0.953421  0.360648  0.431597  0.030185
# 7   0.182527  0.051682  0.620288  0.853434  0.324586
# 8   0.232518  0.034265  0.326712  0.813759  0.010466
# 9    0.34069  0.910038  0.293726  0.109882  0.689943
# 10  0.091192  0.241515  0.235934  0.904396  0.155773
# 11  0.572926  0.409134  0.749495  0.630923  0.079969
# 12  0.191295  0.140298  0.913058  0.403997  0.425318
# 13  0.053545  0.743588  0.045677  0.746104  0.303892
# 14   0.16664  0.416513  0.639310  0.560431  0.028280
# 15  0.107258  0.495714  0.475065  0.080409  0.186404
# 16  0.225552  0.418660  0.071517  0.725478  0.459326
# ...

# %%
#updating by using location(index) of rows and column first value is of row second is of column
newdf.loc[0,'A']=8976

# %%
newdf
# Out:
#            A         B         C         D         E
# 0       8976  0.071505  0.269820  0.089495  0.079508
# 1   0.116828  0.467167  0.108266  0.682470  0.455040
# 2   0.057368  0.589525  0.850322  0.737719  0.963583
# 3   0.794483  0.859540  0.421362  0.375615  0.444670
# 4   0.232749  0.823588  0.982229  0.002032  0.332501
# 5   0.970108  0.267476  0.327169  0.862918  0.768812
# 6   0.102828  0.953421  0.360648  0.431597  0.030185
# 7   0.182527  0.051682  0.620288  0.853434  0.324586
# 8   0.232518  0.034265  0.326712  0.813759  0.010466
# 9    0.34069  0.910038  0.293726  0.109882  0.689943
# 10  0.091192  0.241515  0.235934  0.904396  0.155773
# 11  0.572926  0.409134  0.749495  0.630923  0.079969
# 12  0.191295  0.140298  0.913058  0.403997  0.425318
# 13  0.053545  0.743588  0.045677  0.746104  0.303892
# 14   0.16664  0.416513  0.639310  0.560431  0.028280
# 15  0.107258  0.495714  0.475065  0.080409  0.186404
# 16  0.225552  0.418660  0.071517  0.725478  0.459326
# ...

# %%
newdf.drop(0,axis=1)  #to drop a column axis=1 is column axis=0 is row
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\CODE\PANDAS\Pandas\basic pandas.ipynb Cell 42' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/CODE/PANDAS/Pandas/basic%20pandas.ipynb#ch0000041?line=0'>1</a> newdf.drop(0,axis=1)
#
# File c:\Users\nav7u\miniconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\nav7u\miniconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
newdf.drop(49,axis=0)
# Out:
#            A         B         C         D         E
# 0       8976  0.071505  0.269820  0.089495  0.079508
# 1   0.116828  0.467167  0.108266  0.682470  0.455040
# 2   0.057368  0.589525  0.850322  0.737719  0.963583
# 3   0.794483  0.859540  0.421362  0.375615  0.444670
# 4   0.232749  0.823588  0.982229  0.002032  0.332501
# 5   0.970108  0.267476  0.327169  0.862918  0.768812
# 6   0.102828  0.953421  0.360648  0.431597  0.030185
# 7   0.182527  0.051682  0.620288  0.853434  0.324586
# 8   0.232518  0.034265  0.326712  0.813759  0.010466
# 9    0.34069  0.910038  0.293726  0.109882  0.689943
# 10  0.091192  0.241515  0.235934  0.904396  0.155773
# 11  0.572926  0.409134  0.749495  0.630923  0.079969
# 12  0.191295  0.140298  0.913058  0.403997  0.425318
# 13  0.053545  0.743588  0.045677  0.746104  0.303892
# 14   0.16664  0.416513  0.639310  0.560431  0.028280
# 15  0.107258  0.495714  0.475065  0.080409  0.186404
# 16  0.225552  0.418660  0.071517  0.725478  0.459326
# ...

# %%
newdf.loc[[1,2],:]   # to see row with all column
# Out:
#           A         B         C         D         E
# 1  0.116828  0.467167  0.108266  0.682470  0.455040
# 2  0.057368  0.589525  0.850322  0.737719  0.963583

# %%
newdf.loc[:,['C','D']]   # to see column with al row
# Out:
#            C         D
# 0   0.269820  0.089495
# 1   0.108266  0.682470
# 2   0.850322  0.737719
# 3   0.421362  0.375615
# 4   0.982229  0.002032
# 5   0.327169  0.862918
# 6   0.360648  0.431597
# 7   0.620288  0.853434
# 8   0.326712  0.813759
# 9   0.293726  0.109882
# 10  0.235934  0.904396
# 11  0.749495  0.630923
# 12  0.913058  0.403997
# 13  0.045677  0.746104
# 14  0.639310  0.560431
# 15  0.475065  0.080409
# 16  0.071517  0.725478
# 17  0.177288  0.117249
# 18  0.413331  0.076533
# 19  0.597712  0.879933
# 20  0.375828  0.624042
# 21  0.322760  0.416222
# 22  0.779036  0.814483
# 23  0.719197  0.463007
# 24  0.388017  0.655917
# 25  0.815575  0.389771
# 26  0.942685  0.018160
# 27  0.736021  0.022851
# 28  0.913124  0.675672
# 29  0.253696  0.496321
# 30  0.720963  0.037607
# 31  0.683077  0.606785
# 32  0.424514  0.725927
# 33  0.452873  0.191608
# 34  0.751959  0.294343
# 35  0.146774  0.255906
# 36  0.636425  0.798807
# 37  0.214305  0.361749
# 38  0.761156  0.174534
# ...

# %%
newdf.loc[(newdf['A']<0.3)]  #rows having value less than 0.3
# Out:
#            A         B         C         D         E
# 1   0.116828  0.467167  0.108266  0.682470  0.455040
# 2   0.057368  0.589525  0.850322  0.737719  0.963583
# 4   0.232749  0.823588  0.982229  0.002032  0.332501
# 6   0.102828  0.953421  0.360648  0.431597  0.030185
# 7   0.182527  0.051682  0.620288  0.853434  0.324586
# 8   0.232518  0.034265  0.326712  0.813759  0.010466
# 10  0.091192  0.241515  0.235934  0.904396  0.155773
# 12  0.191295  0.140298  0.913058  0.403997  0.425318
# 13  0.053545  0.743588  0.045677  0.746104  0.303892
# 14   0.16664  0.416513  0.639310  0.560431  0.028280
# 15  0.107258  0.495714  0.475065  0.080409  0.186404
# 16  0.225552  0.418660  0.071517  0.725478  0.459326
# 19   0.21145  0.736013  0.597712  0.879933  0.299553
# 25  0.284631  0.868846  0.815575  0.389771  0.899431
# 26  0.025947  0.207675  0.942685  0.018160  0.883281
# 30  0.124893  0.577283  0.720963  0.037607  0.551044
# 33  0.088259  0.524868  0.452873  0.191608  0.772444
# ...

# %%
newdf.loc[(newdf['A']<0.3) & (newdf['C']>0.1)]  #rows having value less than 0.3
# Out:
#            A         B         C         D         E
# 1   0.116828  0.467167  0.108266  0.682470  0.455040
# 2   0.057368  0.589525  0.850322  0.737719  0.963583
# 4   0.232749  0.823588  0.982229  0.002032  0.332501
# 6   0.102828  0.953421  0.360648  0.431597  0.030185
# 7   0.182527  0.051682  0.620288  0.853434  0.324586
# 8   0.232518  0.034265  0.326712  0.813759  0.010466
# 10  0.091192  0.241515  0.235934  0.904396  0.155773
# 12  0.191295  0.140298  0.913058  0.403997  0.425318
# 14   0.16664  0.416513  0.639310  0.560431  0.028280
# 15  0.107258  0.495714  0.475065  0.080409  0.186404
# 19   0.21145  0.736013  0.597712  0.879933  0.299553
# 25  0.284631  0.868846  0.815575  0.389771  0.899431
# 26  0.025947  0.207675  0.942685  0.018160  0.883281
# 30  0.124893  0.577283  0.720963  0.037607  0.551044
# 33  0.088259  0.524868  0.452873  0.191608  0.772444
# 49   0.28062  0.575135  0.427423  0.233904  0.637763

# %%
#iloc will be use by default index for row and column no matter what is the name of row and column
newdf.iloc[0,0]
# Out:
# 8976

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0      8976  0.071505  0.269820  0.089495  0.079508
# 1  0.116828  0.467167  0.108266  0.682470  0.455040

# %%
newdf.iloc[[0,5],[0,1]]  # it will select particular row and column
# Out:
#           A         B
# 0      8976  0.071505
# 5  0.970108  0.267476

# %%
newdf.iloc[[0,1],[0,1]]
# Out:
#           A         B
# 0      8976  0.071505
# 1  0.116828  0.467167

# %%
newdf.drop(['A','D'],axis=1,inplace=True)  # inplace will modify original data there itself

# %%
newdf.drop(0,axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\CODE\PANDAS\Pandas\basic pandas.ipynb Cell 53' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/CODE/PANDAS/Pandas/basic%20pandas.ipynb#ch0000052?line=0'>1</a> newdf.drop(0,axis=1,inplace=True)
#
# File c:\Users\nav7u\miniconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\nav7u\miniconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
newdf.drop([0,5],axis=0,inplace=True)

# %%
newdf
# Out:
#            B         C         E
# 1   0.467167  0.108266  0.455040
# 2   0.589525  0.850322  0.963583
# 3   0.859540  0.421362  0.444670
# 4   0.823588  0.982229  0.332501
# 6   0.953421  0.360648  0.030185
# 7   0.051682  0.620288  0.324586
# 8   0.034265  0.326712  0.010466
# 9   0.910038  0.293726  0.689943
# 10  0.241515  0.235934  0.155773
# 11  0.409134  0.749495  0.079969
# 12  0.140298  0.913058  0.425318
# 13  0.743588  0.045677  0.303892
# 14  0.416513  0.639310  0.028280
# 15  0.495714  0.475065  0.186404
# 16  0.418660  0.071517  0.459326
# 17  0.328496  0.177288  0.213418
# 18  0.495950  0.413331  0.928598
# 19  0.736013  0.597712  0.299553
# 20  0.513588  0.375828  0.240987
# 21  0.561601  0.322760  0.866461
# 22  0.422119  0.779036  0.494676
# 23  0.546383  0.719197  0.093087
# 24  0.508662  0.388017  0.313429
# 25  0.868846  0.815575  0.899431
# 26  0.207675  0.942685  0.883281
# 27  0.051620  0.736021  0.768472
# 28  0.022638  0.913124  0.863364
# ...

# %%
newdf.reset_index(drop=True,inplace=True)  #to reset index

# %%
newdf.head(4)
# Out:
#           B         C         E
# 0  0.467167  0.108266  0.455040
# 1  0.589525  0.850322  0.963583
# 2  0.859540  0.421362  0.444670
# 3  0.823588  0.982229  0.332501

# %%
newdf.iloc[:3,1:]
# Out:
#           C         E
# 0  0.108266  0.455040
# 1  0.850322  0.963583
# 2  0.421362  0.444670

# %%
newdf.iloc[4:7,2:3]
# Out:
#           E
# 4  0.030185
# 5  0.324586
# 6  0.010466

# %%
newdf['B']=56

# %%
newdf["B"].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# Name: B, dtype: bool

# %%
newdf
# Out:
#      B         C         E
# 0   56  0.108266  0.455040
# 1   56  0.850322  0.963583
# 2   56  0.421362  0.444670
# 3   56  0.982229  0.332501
# 4   56  0.360648  0.030185
# 5   56  0.620288  0.324586
# 6   56  0.326712  0.010466
# 7   56  0.293726  0.689943
# 8   56  0.235934  0.155773
# 9   56  0.749495  0.079969
# 10  56  0.913058  0.425318
# 11  56  0.045677  0.303892
# 12  56  0.639310  0.028280
# 13  56  0.475065  0.186404
# 14  56  0.071517  0.459326
# 15  56  0.177288  0.213418
# 16  56  0.413331  0.928598
# 17  56  0.597712  0.299553
# 18  56  0.375828  0.240987
# 19  56  0.322760  0.866461
# 20  56  0.779036  0.494676
# 21  56  0.719197  0.093087
# 22  56  0.388017  0.313429
# 23  56  0.815575  0.899431
# 24  56  0.942685  0.883281
# 25  56  0.736021  0.768472
# 26  56  0.913124  0.863364
# 27  56  0.253696  0.924228
# 28  56  0.720963  0.551044
# 29  56  0.683077  0.392027
# 30  56  0.424514  0.237899
# 31  56  0.452873  0.772444
# 32  56  0.751959  0.066839
# ...

# %%
newdf.shape
# Out:
# (48, 3)

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   B       48 non-null     int64
#  1   C       48 non-null     float64
#  2   E       48 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 1.2 KB

# %%
df1 = pd.DataFrame({"name": ['Alfred', 'Batman', 'Alfred'],
                   "toy": [np.nan, np.nan, np.nan],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df1
# Out:
#      name  toy       born
# 0  Alfred  NaN        NaT
# 1  Batman  NaN 1940-04-25
# 2  Alfred  NaN        NaT

# %%
df1.dropna() # by default it drop rows having any NA value
# Out:
# Empty DataFrame
# Columns: [name, toy, born]
# Index: []

# %%
# drops column with all none value
df1.dropna(how='all',axis=1)
# Out:
#      name       born
# 0  Alfred        NaT
# 1  Batman 1940-04-25
# 2  Alfred        NaT

# %%
df1.drop_duplicates(subset=['name'],keep='first')
# Out:
#      name  toy       born
# 0  Alfred  NaN        NaT
# 1  Batman  NaN 1940-04-25

# %%
df1.drop_duplicates(subset=['name'],keep='last')
# Out:
#      name  toy       born
# 1  Batman  NaN 1940-04-25
# 2  Alfred  NaN        NaT

# %%
df1.drop_duplicates(subset=['name'],keep=False)
# Out:
#      name  toy       born
# 1  Batman  NaN 1940-04-25

# %%
df1['name'].value_counts(dropna=False)
# Out:
# Alfred    2
# Batman    1
# Name: name, dtype: int64

# %%
df3=pd.read_excel('Book1.xlsx')

# %%
df3
# Out:
#          Date       Open*        High         Low     Close**  \
# 0  2022-07-04  $19,297.31  $20,258.75  $19,063.07  $20,231.26
# 1  2022-07-03  $19,242.09  $19,558.27  $18,966.95  $19,297.08
# 2  2022-07-02  $19,274.84  $19,371.75  $19,027.08  $19,242.26
# 3  2022-07-01  $19,820.47  $20,632.67  $19,073.71  $19,269.37
# 4  2022-06-30  $20,108.31  $20,141.16  $18,729.66  $19,784.73
# 5  2022-06-29  $20,281.17  $20,364.16  $19,937.79  $20,104.02
# 6  2022-06-28  $20,731.54  $21,164.42  $20,228.81  $20,280.64
# 7  2022-06-27  $21,028.24  $21,478.09  $20,620.20  $20,735.48
# 8  2022-06-26  $21,496.49  $21,783.72  $21,016.27  $21,027.30
# 9  2022-06-25  $21,233.61  $21,520.91  $20,964.59  $21,502.34
# 10 2022-06-24  $21,084.65  $21,472.92  $20,777.51  $21,231.66
# 11 2022-06-23  $19,986.61  $21,135.76  $19,950.12  $21,085.88
# 12 2022-06-22  $20,719.41  $20,835.75  $19,848.08  $19,987.03
# 13 2022-06-21  $20,594.29  $21,620.63  $20,415.06  $20,710.60
# ...

# %%
pd.read_excel('Book1.xlsx',sheet_name='Sheet2')
# Out:
#        Date2       Open2       High2        Low2      Close2          Volume2  \
# 0 2022-07-04  $19,297.31  $20,258.75  $19,063.07  $20,231.26  $21,594,638,208
# 1 2022-07-03  $19,242.09  $19,558.27  $18,966.95  $19,297.08  $16,390,821,947
# 2 2022-07-02  $19,274.84  $19,371.75  $19,027.08  $19,242.26  $18,100,418,740
# 3 2022-07-01  $19,820.47  $20,632.67  $19,073.71  $19,269.37  $30,767,551,159
#
#         Market Cap2
# 0  $386,119,553,712
# 1  $368,272,636,368
# 2  $367,208,487,557
# 3  $367,709,366,219
